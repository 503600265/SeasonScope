# %%
# import requests
# import os
# import time
# from urllib.request import urlretrieve
# import zipfile
# import json

# # Constants
# CLIENT_ID = "K6CoLtLotPMpUO3RO9cQXqwNHFKHRuAxTig9H0t6VdY"  # Replace with your actual key
# SEASON = "winter"
# IMAGE_COUNT = {"train": 6000, "validation": 1500, "test": 1500}
# PER_PAGE = 30
# BASE_PATH = "/content/project"
# SECONDS_BETWEEN_REQUESTS = 72  # Throttle requests to stay under rate limit
# PROGRESS_FILE = "/content/download_progress_winter.json"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Function to fetch images
# def get_unsplash_photos(keyword, client_id, page, per_page=PER_PAGE):
#     url = "https://api.unsplash.com/search/photos"
#     params = {"query": keyword, "client_id": client_id, "per_page": per_page, "page": page}
#     response = requests.get(url, params=params)
#     if response.status_code == 200:
#         return [photo['urls']['regular'] for photo in response.json()['results']]
#     else:
#         print(f"Failed to fetch photos for {keyword}, page {page}: {response.status_code}")
#         return []

# # Function to download and save images with custom filenames
# def download_and_save_images(image_urls, folder_path, image_name, start_index):
#     if not os.path.exists(folder_path):
#         os.makedirs(folder_path)
#     for i, url in enumerate(image_urls, start=start_index):
#         filename = f"{folder_path}/{image_name}_{i}.jpg"
#         urlretrieve(url, filename)

# # # Function to download images for a season and dataset part
# def download_season_images(season, part, target_count, progress):
#     folder_name = os.path.join(BASE_PATH, season, part)
#     current_page = progress.get(season, {}).get(part, 1)
#     downloaded_count = (current_page - 1) * PER_PAGE
#     start_index = downloaded_count

#     while downloaded_count < target_count:
#         image_urls = get_unsplash_photos(season, CLIENT_ID, current_page)
#         download_and_save_images(image_urls, folder_name, season.capitalize(), start_index)
#         print(f"Successfully downloaded photo {start_index} on {current_page}")
#         downloaded_count += len(image_urls)
#         current_page += 1
#         start_index += len(image_urls)
#         save_progress(season, part, current_page)
#         if downloaded_count < target_count:
#             time.sleep(SECONDS_BETWEEN_REQUESTS)  # Throttle requests


# # Save progress to a file
# def save_progress(season, part, page):
#     if os.path.exists(PROGRESS_FILE):
#         with open(PROGRESS_FILE, 'r') as file:
#             progress = json.load(file)
#     else:
#         progress = {}

#     if season not in progress:
#         progress[season] = {}
#     progress[season][part] = page

#     with open(PROGRESS_FILE, 'w') as file:
#         json.dump(progress, file)

# # Load progress from a file
# def load_progress():
#     if os.path.exists(PROGRESS_FILE):
#         with open(PROGRESS_FILE, 'r') as file:
#             return json.load(file)
#     return {}

# # Zip the folders
# def zip_folders():
#     with zipfile.ZipFile('/content/project.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
#         for root, dirs, files in os.walk(BASE_PATH):
#             for file in files:
#                 zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), BASE_PATH))

# %%
# # Main download loop with progress tracking
# progress = load_progress()
# for part, count in IMAGE_COUNT.items():
#     download_season_images(SEASON, part, count, progress)

# zip_folders()
# print("Zipping complete. Download '/content/project.zip'")

# %%
import requests
import os
import time
from urllib.request import urlretrieve
import zipfile
import json

# Constants
CLIENT_ID = "K6CoLtLotPMpUO3RO9cQXqwNHFKHRuAxTig9H0t6VdY"  # Replace with your actual Unsplash Access Key
SEASON = "winter"  # Adjust seasons as neededdd
IMAGE_COUNT = {"train": 10000, "validation": 2500, "test": 2500}
PER_PAGE = 10  # Number of images per page
SECONDS_BETWEEN_REQUESTS = 1.2  # Throttle requests to avoid hitting rate limit too quickly
BASE_PATH = "/content/project"  # Base directory for saving images
PROGRESS_FILE = "/content/download_progress.json"  # File to track download progress

# %%
# Function to fetch images from Unsplash
def get_unsplash_photos(keyword, client_id, page, per_page=PER_PAGE):
    url = "https://api.unsplash.com/search/photos"
    params = {"query": keyword, "client_id": client_id, "per_page": per_page, "page": page}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return [photo['urls']['regular'] for photo in response.json()['results']]
        print(f"Successfully downloaded photo {downloaded_count} on {current_page}")

    else:
        print(f"Failed to fetch photos for {keyword}, page {page}: {response.status_code}")
        return []
# Function to download and save images with custom filenames
def download_and_save_images(image_urls, folder_path, image_name, start_index):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    for i, url in enumerate(image_urls, start=start_index):
        filename = f"{folder_path}/{image_name}_{i}.jpg"
        urlretrieve(url, filename)

# Function to download images for a season and dataset part
def download_season_images(season, part, target_count, progress):
    folder_name = os.path.join(BASE_PATH, season, part)
    current_page = progress.get(season, {}).get(part, 1)
    downloaded_count = (current_page - 1) * PER_PAGE

    while downloaded_count < target_count:
        image_urls = get_unsplash_photos(season, CLIENT_ID, current_page)
        download_and_save_images(image_urls, folder_name, season.capitalize(), downloaded_count)
        downloaded_count += len(image_urls)
        current_page += 1
        save_progress(season, part, current_page)
        if downloaded_count < target_count:
            time.sleep(SECONDS_BETWEEN_REQUESTS)  # Throttle requests

# Function to save progress to a file
def save_progress(season, part, page):
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, 'r') as file:
            progress = json.load(file)
    else:
        progress = {}

    if season not in progress:
        progress[season] = {}
    progress[season][part] = page

    with open(PROGRESS_FILE, 'w') as file:
        json.dump(progress, file)

# Function to load progress from a file
def load_progress():
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, 'r') as file:
            return json.load(file)
    return {}

# Function to zip the folders
def zip_folders():
    with zipfile.ZipFile('/content/project.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(BASE_PATH):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), BASE_PATH))

# %%
# Main download loop with progress tracking
progress = load_progress()
for part, count in IMAGE_COUNT.items():
    download_season_images(SEASON, part, count, progress)

zip_folders()
print("Zipping complete. Download '/content/project.zip'")
# Out:
# Successfully downloaded photo 0 on 1
# Successfully downloaded photo 10 on 2
# Successfully downloaded photo 20 on 3
# Successfully downloaded photo 30 on 4
# Successfully downloaded photo 40 on 5
# Successfully downloaded photo 50 on 6
# Successfully downloaded photo 60 on 7
# Successfully downloaded photo 70 on 8
# Successfully downloaded photo 80 on 9
# Successfully downloaded photo 90 on 10
# Successfully downloaded photo 100 on 11
# Successfully downloaded photo 110 on 12
# Successfully downloaded photo 120 on 13
# Successfully downloaded photo 130 on 14
# Successfully downloaded photo 140 on 15
# Successfully downloaded photo 150 on 16
# Successfully downloaded photo 160 on 17
# Successfully downloaded photo 170 on 18
# Successfully downloaded photo 180 on 19
# Successfully downloaded photo 190 on 20
# Successfully downloaded photo 200 on 21
# Successfully downloaded photo 210 on 22
# Successfully downloaded photo 220 on 23
# Successfully downloaded photo 230 on 24
# Successfully downloaded photo 240 on 25
# Successfully downloaded photo 250 on 26
# Successfully downloaded photo 260 on 27
# Successfully downloaded photo 270 on 28
# Successfully downloaded photo 280 on 29
# Successfully downloaded photo 290 on 30
# Failed to fetch photos for winter, page 31: 403
# Successfully downloaded photo 300 on 31
# Failed to fetch photos for winter, page 32: 403
# Successfully downloaded photo 300 on 32
# Failed to fetch photos for winter, page 33: 403
# Successfully downloaded photo 300 on 33
# Failed to fetch photos for winter, page 34: 403
# Successfully downloaded photo 300 on 34
# Failed to fetch photos for winter, page 35: 403
# Successfully downloaded photo 300 on 35
# Failed to fetch photos for winter, page 36: 403
# Successfully downloaded photo 300 on 36
# Failed to fetch photos for winter, page 37: 403
# Successfully downloaded photo 300 on 37
# Failed to fetch photos for winter, page 38: 403
# Successfully downloaded photo 300 on 38
# Failed to fetch photos for winter, page 39: 403
# Successfully downloaded photo 300 on 39
# Failed to fetch photos for winter, page 40: 403
# Successfully downloaded photo 300 on 40
# Failed to fetch photos for winter, page 41: 403
# Successfully downloaded photo 300 on 41
# Failed to fetch photos for winter, page 42: 403
# Successfully downloaded photo 300 on 42
# Failed to fetch photos for winter, page 43: 403
# Successfully downloaded photo 300 on 43
# Failed to fetch photos for winter, page 44: 403
# Successfully downloaded photo 300 on 44
# Failed to fetch photos for winter, page 45: 403
# Successfully downloaded photo 300 on 45
# Failed to fetch photos for winter, page 46: 403
# Successfully downloaded photo 300 on 46
# Failed to fetch photos for winter, page 47: 403
# Successfully downloaded photo 300 on 47
# Failed to fetch photos for winter, page 48: 403
# Successfully downloaded photo 300 on 48
# Failed to fetch photos for winter, page 49: 403
# Successfully downloaded photo 300 on 49
# Failed to fetch photos for winter, page 50: 403
# Successfully downloaded photo 300 on 50
# Failed to fetch photos for winter, page 51: 403
# Successfully downloaded photo 300 on 51
# Failed to fetch photos for winter, page 52: 403
# Successfully downloaded photo 300 on 52
# Failed to fetch photos for winter, page 53: 403
# Successfully downloaded photo 300 on 53
# Failed to fetch photos for winter, page 54: 403
# Successfully downloaded photo 300 on 54
# Failed to fetch photos for winter, page 55: 403
# Successfully downloaded photo 300 on 55
# Failed to fetch photos for winter, page 56: 403
# Successfully downloaded photo 300 on 56
# Failed to fetch photos for winter, page 57: 403
# Successfully downloaded photo 300 on 57
# Failed to fetch photos for winter, page 58: 403
# Successfully downloaded photo 300 on 58
# Failed to fetch photos for winter, page 59: 403
# Successfully downloaded photo 300 on 59
# Failed to fetch photos for winter, page 60: 403
# Successfully downloaded photo 300 on 60
# Failed to fetch photos for winter, page 61: 403
# Successfully downloaded photo 300 on 61
# Failed to fetch photos for winter, page 62: 403
# Successfully downloaded photo 300 on 62
# Failed to fetch photos for winter, page 63: 403
# Successfully downloaded photo 300 on 63
# Failed to fetch photos for winter, page 64: 403
# Successfully downloaded photo 300 on 64
# Failed to fetch photos for winter, page 65: 403
# Successfully downloaded photo 300 on 65
# Failed to fetch photos for winter, page 66: 403
# Successfully downloaded photo 300 on 66
# Failed to fetch photos for winter, page 67: 403
# Successfully downloaded photo 300 on 67
# Failed to fetch photos for winter, page 68: 403
# Successfully downloaded photo 300 on 68
# Failed to fetch photos for winter, page 69: 403
# Successfully downloaded photo 300 on 69
# Failed to fetch photos for winter, page 70: 403
# Successfully downloaded photo 300 on 70
# Failed to fetch photos for winter, page 71: 403
# Successfully downloaded photo 300 on 71
# Failed to fetch photos for winter, page 72: 403
# Successfully downloaded photo 300 on 72
# Failed to fetch photos for winter, page 73: 403
# Successfully downloaded photo 300 on 73
# Failed to fetch photos for winter, page 74: 403
# Successfully downloaded photo 300 on 74
# Failed to fetch photos for winter, page 75: 403
# Successfully downloaded photo 300 on 75
# Failed to fetch photos for winter, page 76: 403
# Successfully downloaded photo 300 on 76
# Failed to fetch photos for winter, page 77: 403
# Successfully downloaded photo 300 on 77
# Failed to fetch photos for winter, page 78: 403
# Successfully downloaded photo 300 on 78
# Failed to fetch photos for winter, page 79: 403
# Successfully downloaded photo 300 on 79
# Failed to fetch photos for winter, page 80: 403
# Successfully downloaded photo 300 on 80
# Failed to fetch photos for winter, page 81: 403
# Successfully downloaded photo 300 on 81
# Failed to fetch photos for winter, page 82: 403
# Successfully downloaded photo 300 on 82
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-52dde5145e2e> in <cell line: 3>()
#       2 progress = load_progress()
#       3 for part, count in IMAGE_COUNT.items():
# ----> 4     download_season_images(SEASON, part, count, progress)
#       5
#       6 zip_folders()
#
# <ipython-input-3-a5e84480dba6> in download_season_images(season, part, target_count, progress)
#      32         save_progress(season, part, current_page)
#      33         if downloaded_count < target_count:
# ---> 34             time.sleep(SECONDS_BETWEEN_REQUESTS)  # Throttle requests
#      35
#      36 # Function to save progress to a file
#
# KeyboardInterrupt:
